# %%
import pandas as pd
from pathlib import Path

# ---- Update these paths if needed ----
ESM_XLSX = Path("./delta_esm_per_ha_2100_regions_aff.xlsx")
IAM_XLSX = Path("./carbon_density_afforestation_R10_SSP1_SPA1_26I_D_results.xlsx")

# Potential region column name candidates
REGION_CANDIDATES = [
    "region","Region","REGION",
    "R10","R14","R5","AR6_REGION","AR6","world_region"
]

SCENARIO_CANDIDATES = [
    "SSP","scenario","Scenario","SCENARIO"
]

def detect_first(df, candidates):
    for c in candidates:
        if c in df.columns:
            return c
    # fallback heuristic
    for col in df.columns:
        low = col.lower()
        if any(key in low for key in ["region"]) and "sub" not in low:
            return col
    return None

print("Reading ESM file:", ESM_XLSX)
esm_df = pd.read_excel(ESM_XLSX)
print("Reading IAM file:", IAM_XLSX)
iam_df = pd.read_excel(IAM_XLSX)

print("\n================= COLUMN NAMES =================")
print("ESM columns:")
print(list(esm_df.columns))
print("\nIAM columns:")
print(list(iam_df.columns))

esm_region_col = detect_first(esm_df, REGION_CANDIDATES)
iam_region_col = detect_first(iam_df, REGION_CANDIDATES)

esm_scenario_col = detect_first(esm_df, SCENARIO_CANDIDATES)
iam_scenario_col = detect_first(iam_df, SCENARIO_CANDIDATES)

print("\n================= DETECTED KEYS =================")
print(f"ESM region column: {esm_region_col}")
print(f"IAM region column: {iam_region_col}")
print(f"ESM scenario column: {esm_scenario_col}")
print(f"IAM scenario column: {iam_scenario_col}")

def show_regions(df, region_col, label):
    if region_col is None:
        print(f"\n{label}: No region column detected.")
        return
    regions = df[region_col].dropna().astype(str)
    unique = sorted(regions.unique())
    print(f"\n{label}: Region summary")
    print(f"  Column name: {region_col}")
    print(f"  Count rows (non-null): {len(regions)}")
    print(f"  Unique region count: {len(unique)}")
    print(f"  Regions list ({len(unique)}):")
    print(unique)

show_regions(esm_df, esm_region_col, "ESM")
show_regions(iam_df, iam_region_col, "IAM")

print("\n================= NOTES =================")
print("1. Verify that detected region & scenario columns are correct.")
print("2. If a column wasn't detected, tell me its actual name.")
print("3. Next step will harmonize scenario and region names before scaling.")
print("4. If you already know certain region name mappings, you can list them now.")
# Out:
# Reading ESM file: /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/delta_esm_per_ha_2100_regions_aff.xlsx
# Reading IAM file: /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/carbon_density_afforestation_R10_SSP1_SPA1_26I_D_results.xlsx
#
# ================= COLUMN NAMES =================
# ESM columns:
# ['Model', 'ESM', 'SSP', 'Transition', 'Region', 'RegionIndex', 'Carbon_Density_tCO2_per_ha', 'LastYear']
#
# IAM columns:
# ['Scenario', 'Model', 'Region', 'Carbon_Density_tCO2_per_ha']
#
# ================= DETECTED KEYS =================
# ESM region column: Region
# IAM region column: Region
# ESM scenario column: SSP
# IAM scenario column: Scenario
#
# ESM: Region summary
#   Column name: Region
#   Count rows (non-null): 297
#   Unique region count: 11
#   Regions list (11):
# ['Africa', 'Asia-Pacific', 'Eastern Asia', 'Eurasia', 'Europe', 'Latin America and Caribbean', 'Middle East', 'North America', 'South-East Asia and developing Pacific', 'Southern Asia', 'World']
#
# IAM: Region summary
#   Column name: Region
#   Count rows (non-null): 10
#   Unique region count: 10
#   Regions list (10):
# ['R10AFRICA', 'R10CHINA+', 'R10EUROPE', 'R10INDIA+', 'R10LATIN_AM', 'R10MIDDLE_EAST', 'R10NORTH_AM', 'R10PAC_OECD', 'R10REF_ECON', 'R10REST_ASIA']
#
# ================= NOTES =================
# 1. Verify that detected region & scenario columns are correct.
# 2. If a column wasn't detected, tell me its actual name.
# 3. Next step will harmonize scenario and region names before scaling.
# 4. If you already know certain region name mappings, you can list them now.

# %%
import pandas as pd
from pathlib import Path

# ---------------- CONFIG ----------------
ESM_XLSX = Path("./delta_esm_per_ha_2100_regions_aff.xlsx")
IAM_XLSX = Path("./carbon_density_afforestation_R10_SSP1_SPA1_26I_D_results.xlsx")

OUTPUT_XLSX = Path("scaling_factors_regions_aff_ssp126_paper.xlsx")
OUTPUT_CSV  = Path("scaling_factors_regions_aff_ssp126_paper.csv")

CANONICAL_SCENARIO = "SSP1-26"

# Region mapping
REGION_MAP = {
    "Africa": "R10AFRICA",
    "Europe": "R10EUROPE",
    "Latin America and Caribbean": "R10LATIN_AM",
    "Middle East": "R10MIDDLE_EAST",
    "North America": "R10NORTH_AM",
    "Eastern Asia": "R10CHINA+",
    "Southern Asia": "R10INDIA+",
    "Asia-Pacific": "R10PAC_OECD",
    "Eurasia": "R10REF_ECON",
    "South-East Asia and developing Pacific": "R10REST_ASIA",
}

# Column names in ESM file
LSM_MODEL_COL = "Model"          # Land Surface Model (e.g., jules)
ESM_MODEL_COL = "ESM"            # GCM / ESM (e.g., mpi-esm1-2-hr)
ESM_SCENARIO_COL = "SSP"
ESM_REGION_COL = "Region"
ESM_TRANSITION_COL = "Transition"
ESM_CARBON_COL = "Carbon_Density_tCO2_per_ha"

# IAM columns
IAM_SCENARIO_COL = "Scenario"
IAM_REGION_COL = "Region"
IAM_CARBON_COL = "Carbon_Density_tCO2_per_ha"
IAM_MODEL_COL = None  # Set to actual column name if IAM has model splits you want to retain (e.g., "Model")

# If IAM has a model column and you want per-IAM model scaling, set this True
PER_IAM_MODEL = False

# Negative handling: 'keep', 'clip_zero', or 'drop'
NEGATIVE_POLICY = "keep"

# --------------- Helpers ---------------
def normalize_esm_scenario(v):
    return CANONICAL_SCENARIO if isinstance(v, str) and v.lower().strip() == "ssp126" else None

def normalize_iam_scenario(v):
    up = str(v).upper()
    return CANONICAL_SCENARIO if ("SSP1" in up and "26" in up) else None

# --------------- Load ---------------
print("Reading ESM:", ESM_XLSX)
esm = pd.read_excel(ESM_XLSX)
print("Reading IAM:", IAM_XLSX)
iam = pd.read_excel(IAM_XLSX)

# --------------- Scenario normalize ---------------
esm["SSP_std"] = esm[ESM_SCENARIO_COL].apply(normalize_esm_scenario)
iam["SSP_std"] = iam[IAM_SCENARIO_COL].apply(normalize_iam_scenario)

esm = esm[esm["SSP_std"] == CANONICAL_SCENARIO].copy()
iam = iam[iam["SSP_std"] == CANONICAL_SCENARIO].copy()

print("\nAfter scenario filter:")
print("  ESM rows:", len(esm))
print("  IAM rows:", len(iam))

# --------------- Region mapping ---------------
esm = esm[esm[ESM_REGION_COL] != "World"].copy()
esm["Region_mapped"] = esm[ESM_REGION_COL].map(REGION_MAP)

unmapped_regions = esm[esm["Region_mapped"].isna()][ESM_REGION_COL].unique()
if len(unmapped_regions) > 0:
    print("WARNING: Unmapped ESM regions (dropping):", unmapped_regions)
    esm = esm[esm["Region_mapped"].notna()].copy()

# --------------- Negative handling ---------------
neg_mask = esm[ESM_CARBON_COL] < 0
neg_count = neg_mask.sum()
if neg_count > 0:
    print(f"\nNOTE: {neg_count} ESM rows have negative carbon density (e.g., min={esm[ESM_CARBON_COL].min():.3f}). Policy: {NEGATIVE_POLICY}")
    if NEGATIVE_POLICY == "clip_zero":
        esm.loc[neg_mask, ESM_CARBON_COL] = 0.0
    elif NEGATIVE_POLICY == "drop":
        esm = esm.loc[~neg_mask].copy()

# --------------- Prepare IAM regions ---------------
iam = iam.rename(columns={IAM_REGION_COL: "Region_mapped"})

if IAM_MODEL_COL and PER_IAM_MODEL:
    # keep IAM model column
    pass
else:
    # aggregate across IAM model dimension if present (mean)
    group_keys = ["SSP_std", "Region_mapped"]
    iam = (iam
           .groupby(group_keys, as_index=False)
           .agg({IAM_CARBON_COL: "mean"}))

# --------------- ESM granularity aggregation ---------------
# If there are duplicate rows for same (SSP_std, ESM, LSM, Transition, Region_mapped), average them
esm_grouped = (esm
    .groupby(["SSP_std", ESM_MODEL_COL, LSM_MODEL_COL, ESM_TRANSITION_COL, "Region_mapped"], as_index=False)
    .agg({ESM_CARBON_COL: "mean"})
    .rename(columns={ESM_CARBON_COL: "ESM_CarbonDensity"}))

# --------------- IAM grouped ---------------
if IAM_MODEL_COL and PER_IAM_MODEL:
    iam_grouped = (iam
        .groupby(["SSP_std", IAM_MODEL_COL, "Region_mapped"], as_index=False)
        .agg({IAM_CARBON_COL: "mean"})
        .rename(columns={IAM_CARBON_COL: "IAM_CarbonDensity", IAM_MODEL_COL: "IAM_Model"}))
else:
    iam_grouped = iam.rename(columns={IAM_CARBON_COL: "IAM_CarbonDensity"})

print("\nESM grouped rows:", len(esm_grouped))
print("IAM grouped rows:", len(iam_grouped))

# --------------- Merge ---------------
if IAM_MODEL_COL and PER_IAM_MODEL:
    merged = esm_grouped.merge(iam_grouped, on=["SSP_std", "Region_mapped"], how="inner", validate="many_to_many")
else:
    merged = esm_grouped.merge(iam_grouped, on=["SSP_std", "Region_mapped"], how="inner", validate="many_to_one")

# --------------- Scaling ---------------
merged = merged[merged["IAM_CarbonDensity"] != 0].copy()
merged["scaling_factor"] = merged["ESM_CarbonDensity"] / merged["IAM_CarbonDensity"]

# Column ordering
cols = ["SSP_std", "Region_mapped", ESM_MODEL_COL, LSM_MODEL_COL, ESM_TRANSITION_COL,
        "ESM_CarbonDensity", "IAM_CarbonDensity", "scaling_factor"]
if "IAM_Model" in merged.columns:
    cols.insert(5, "IAM_Model")
merged = merged[cols].sort_values(["SSP_std", ESM_MODEL_COL, LSM_MODEL_COL, ESM_TRANSITION_COL, "Region_mapped"]).reset_index(drop=True)

print("\nPreview (first 15 rows):")
print(merged.head(15))

# Coverage diagnostics
expected_keys = esm_grouped[["SSP_std", ESM_MODEL_COL, LSM_MODEL_COL, ESM_TRANSITION_COL, "Region_mapped"]].drop_duplicates()
matched_keys = merged[["SSP_std", ESM_MODEL_COL, LSM_MODEL_COL, ESM_TRANSITION_COL, "Region_mapped"]].drop_duplicates()
missing = (expected_keys
           .merge(matched_keys, how="left", indicator=True)
           .query('_merge == \"left_only\"')
           .drop(columns="_merge"))
if not missing.empty:
    print("\nWARNING: Missing IAM matches for some ESM combinations:")
    print(missing.head(15))
    print("Total missing combinations:", len(missing))
else:
    print("\nAll ESM combinations matched IAM data (after filtering).")

# --------------- Save ---------------
OUTPUT_XLSX.parent.mkdir(parents=True, exist_ok=True)
merged.to_excel(OUTPUT_XLSX, index=False)
merged.to_csv(OUTPUT_CSV, index=False)
print(f"\nSaved scaling factors to:\n  {OUTPUT_XLSX.resolve()}\n  {OUTPUT_CSV.resolve()}")

# --------------- Stats ---------------
print("\nScaling factor stats:")
print(merged["scaling_factor"].describe())

# Simple outlier flag (> 99th or < 1st percentile)
low_thr = merged["scaling_factor"].quantile(0.01)
high_thr = merged["scaling_factor"].quantile(0.99)
outliers = merged[(merged["scaling_factor"] < low_thr) | (merged["scaling_factor"] > high_thr)]
if not outliers.empty:
    print(f"\nPotential extreme outliers outside 1st–99th percentile ({len(outliers)} rows). Examples:")
    print(outliers.head(10))
# Out:
# Reading ESM: /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/delta_esm_per_ha_2100_regions_aff.xlsx
# Reading IAM: /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/carbon_density_afforestation_R10_SSP1_SPA1_26I_D_results.xlsx
#
# After scenario filter:
#   ESM rows: 297
#   IAM rows: 10
#
# NOTE: 90 ESM rows have negative carbon density (e.g., min=-16.395). Policy: keep
#
# ESM grouped rows: 270
# IAM grouped rows: 10
#
# Preview (first 15 rows):
#     SSP_std   Region_mapped           ESM Model Transition  ESM_CarbonDensity  \
# 0   SSP1-26       R10AFRICA  ipsl-cm6a-lr   clm    agtoaff             53.935
# 1   SSP1-26       R10CHINA+  ipsl-cm6a-lr   clm    agtoaff            120.352
# 2   SSP1-26       R10EUROPE  ipsl-cm6a-lr   clm    agtoaff             86.025
# 3   SSP1-26       R10INDIA+  ipsl-cm6a-lr   clm    agtoaff            115.665
# 4   SSP1-26     R10LATIN_AM  ipsl-cm6a-lr   clm    agtoaff             59.118
# 5   SSP1-26  R10MIDDLE_EAST  ipsl-cm6a-lr   clm    agtoaff            269.279
# 6   SSP1-26     R10NORTH_AM  ipsl-cm6a-lr   clm    agtoaff             50.828
# 7   SSP1-26     R10PAC_OECD  ipsl-cm6a-lr   clm    agtoaff             44.870
# 8   SSP1-26     R10REF_ECON  ipsl-cm6a-lr   clm    agtoaff             32.362
# 9   SSP1-26    R10REST_ASIA  ipsl-cm6a-lr   clm    agtoaff            115.936
# 10  SSP1-26       R10AFRICA  ipsl-cm6a-lr   clm    agtonat             15.315
# 11  SSP1-26       R10CHINA+  ipsl-cm6a-lr   clm    agtonat             38.869
# 12  SSP1-26       R10EUROPE  ipsl-cm6a-lr   clm    agtonat             27.645
# 13  SSP1-26       R10INDIA+  ipsl-cm6a-lr   clm    agtonat             46.060
# 14  SSP1-26     R10LATIN_AM  ipsl-cm6a-lr   clm    agtonat             16.650
#
#     IAM_CarbonDensity  scaling_factor
# 0          517.756948        0.104170
# 1          164.864968        0.730003
# 2          282.338261        0.304688
# 3          119.611970        0.967002
# 4          561.586503        0.105270
# 5          230.384987        1.168822
# 6          140.639884        0.361405
# 7          347.910557        0.128970
# 8           73.401094        0.440893
# 9          437.071869        0.265256
# 10         517.756948        0.029580
# 11         164.864968        0.235763
# 12         282.338261        0.097914
# 13         119.611970        0.385079
# 14         561.586503        0.029648
#
# All ESM combinations matched IAM data (after filtering).
#
# Saved scaling factors to:
#   /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/scaling_factors_regions_aff_ssp126_paper.xlsx
#   /Users/skalidin/Documents/imperial/Reading_Research/ESM_2025/DATA_carbon_AR6_Imputation/scaling_factors_regions_aff_ssp126_paper.csv
#
# Scaling factor stats:
# count    270.000000
# mean       0.146054
# std        0.260616
# min       -0.159494
# 25%       -0.000769
# 50%        0.054874
# 75%        0.161414
# max        1.372980
# Name: scaling_factor, dtype: float64
#
# Potential extreme outliers outside 1st–99th percentile (6 rows). Examples:
#      SSP_std   Region_mapped            ESM  Model Transition  \
# 25   SSP1-26  R10MIDDLE_EAST   ipsl-cm6a-lr    clm   nattoaff
# 68   SSP1-26     R10REF_ECON   ipsl-cm6a-lr  jules   nattoaff
# 115  SSP1-26  R10MIDDLE_EAST  mpi-esm1-2-hr    clm   nattoaff
# 158  SSP1-26     R10REF_ECON  mpi-esm1-2-hr  jules   nattoaff
# 205  SSP1-26  R10MIDDLE_EAST    ukesm1-0-ll    clm   nattoaff
# 248  SSP1-26     R10REF_ECON    ukesm1-0-ll  jules   nattoaff
#
#      ESM_CarbonDensity  IAM_CarbonDensity  scaling_factor
# 25             282.292         230.384987        1.225306
# 68             -10.270          73.401094       -0.139916
# 115            286.933         230.384987        1.245450
# 158             -9.606          73.401094       -0.130870
# 205            316.314         230.384987        1.372980
# 248            -11.707          73.401094       -0.159494
